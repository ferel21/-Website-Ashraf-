# %% [markdown]
# <a href="https://colab.research.google.com/github/ferel21/-Website-Ashraf-/blob/main/T1_Andi_Ashraf_Hak_Bisyu_230907501026_Scrapping_Data_Liputan_Berita.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

def scrape_website(url, user_agent='Mozilla/5.0'):
    print(f"Mengakses URL: {url}")

    # Mengirim permintaan HTTP ke URL target
    try:
        headers = {'User-Agent': user_agent}
        response = requests.get(url, headers=headers)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Error saat mengakses URL: {e}")
        return None

    # Parsing HTML dari halaman web menggunakan BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Menyiapkan list untuk menampung semua data
    collected_data = []

    # Menemukan semua artikel. Di berbagai website, artikel sering dibungkus dalam tag <article>, <div>, atau tag lainnya
    articles = soup.find_all('article')  # Bisa diganti dengan tag atau kelas lainnya
    print(f"Menemukan {len(articles)} total artikel.")

    for article in articles:
        # Mencari judul (misalnya dalam <h2> atau tag lainnya)
        title_tag = article.find('h2')  # Anda bisa ganti tag sesuai dengan struktur website
        if not title_tag:
            continue

        title = title_tag.get_text(strip=True)

        # Mencari link dari tag <a> yang membungkus artikel
        link_tag = article.find('a')
        link = link_tag['href'] if link_tag and link_tag.has_attr('href') else 'Tidak ada link'

        # Mengambil URL Gambar Utama (Image URL)
        image_tag = article.find('img')
        image_url = image_tag['src'] if image_tag and image_tag.has_attr('src') else 'Tidak ada gambar'

        # Mencari kategori atau informasi lain jika ada
        category_tag = article.find('span', class_='category')  # Misalnya kategori ada di <span> dengan class 'category'
        category = category_tag.get_text(strip=True) if category_tag else 'Tidak ada kategori'

        # Mengambil waktu, penulis, atau ringkasan jika ada
        publication_time = 'Tidak ada waktu'
        author = 'Tidak diketahui'
        summary = 'Tidak ada ringkasan'

        # Mengumpulkan data jika judul dan link ditemukan
        if title and link != 'Tidak ada link':
            article_data = {
                'title': title,
                'link': link,
                'category': category,
                'publication_time': publication_time,
                'author': author,
                'image_url': image_url,
                'summary': summary
            }
            collected_data.append(article_data)

    # --- Proses Ekspor Hasil ---
    if not collected_data:
        print("Tidak ada data yang berhasil di-scrape. Mungkin struktur website telah berubah.")
    else:
        print(f"Berhasil mengumpulkan {len(collected_data)} artikel yang valid. Mengekspor ke file...")

        # Mengubah nama file output
        file_name_base = 'scraped_data'

        output_json_data = {"list_post": collected_data}
        with open(f'{file_name_base}.json', 'w', encoding='utf-8') as f:
            json.dump(output_json_data, f, ensure_ascii=False, indent=4)
        print(f"Data berhasil diekspor ke {file_name_base}.json")

        df = pd.DataFrame(collected_data)
        df.to_csv(f'{file_name_base}.csv', index=False, encoding='utf-8')
        print(f"Data berhasil diekspor ke {file_name_base}.csv")

        df.to_excel(f'{file_name_base}.xlsx', index=False)
        print(f"Data berhasil diekspor ke {file_name_base}.xlsx")

    return collected_data

# Gunakan fungsi dengan URL yang berbeda untuk scraping
url = 'https://fajar.co.id/'
scrape_website(url)
# Out:
# Mengakses URL: https://fajar.co.id/
# Menemukan 24 total artikel.
# Berhasil mengumpulkan 24 artikel yang valid. Mengekspor ke file...
# Data berhasil diekspor ke scraped_data.json
# Data berhasil diekspor ke scraped_data.csv
# Data berhasil diekspor ke scraped_data.xlsx
# [{'title': 'Kemenag Jual Kuota Haji hingga Rp1 Miliar, Kerugian Akibat Korupsi Capai Rp1 Triliun, KPK Gandeng PPATK Telusuri Aliran Dana ke PBNU',
#   'link': 'https://fajar.co.id/2025/09/13/kemenag-jual-kuota-haji-hingga-rp1-miliar-kerugian-akibat-korupsi-capai-rp1-triliun-kpk-gandeng-ppatk-telusuri-aliran-dana-ke-pbnu/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2024/07/PANSUS-HAJI-250x190.png',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Prof Henri Sebut UU Jadi Alat Politik: Koruptor Besar Dibiarkan, Aktivis Ditangkap',
#   'link': 'https://fajar.co.id/2025/09/13/prof-henri-sebut-uu-jadi-alat-politik-koruptor-besar-dibiarkan-aktivis-ditangkap/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2022/10/Henry-Subiakto-guru-besar-Universitas-Airlangga-250x190.jpg',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Penyebar Foto Vulgar Hasil Visum Selebgram NR Belum Terungkap, Komisi III Perintahkan Kapolda Sulsel Usut Tuntas',
#   'link': 'https://fajar.co.id/2025/09/13/penyebar-foto-vulgar-hasil-visum-selebgram-nr-belum-terungkap-komisi-iii-perintahkan-kapolda-sulsel-usut-tuntas/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/IMG-20250912-WA0159-250x190.jpg',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Tuntutan Adili Jokowi dan Makzulkan Gibran Mendadak Hilang, 17+8 Ditunggangi?',
#   'link': 'https://fajar.co.id/2025/09/13/tuntutan-adili-jokowi-dan-makzulkan-gibran-mendadak-hilang-178-ditunggangi/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/Screenshot_2025-09-13-12-28-00-504-edit_com.instagram.android-250x190.jpg',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Jokowi Bilang Dirinya Sendiri yang Cari Sekolah untuk Gibran, Dokter Tifa: Masalahnya Dapat Ijazah Apa Tidak Itu?',
#   'link': 'https://fajar.co.id/2025/09/13/jokowi-bilang-dirinya-sendiri-yang-cari-sekolah-untuk-gibran-dokter-tifa-masalahnya-dapat-ijazah-apa-tidak-itu/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/07/IMG_0988-250x190.jpeg',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Prabowo Diingatkan Tidak Serampangan Sebut Ada Potensi Makar dan Terorisme, UGM: Buktinya Tidak Ada',
#   'link': 'https://fajar.co.id/2025/09/13/prabowo-diingatkan-tidak-serampangan-sebut-ada-potensi-makar-dan-terorisme-ugm-buktinya-tidak-ada/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/20250913_113706-250x190.jpg',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Nico Siahaan: Masih Banyak yang Lebih Mendesak Ditindak Dibandingkan Kasus Ferry Irwandi',
#   'link': 'https://fajar.co.id/2025/09/13/nico-siahaan-masih-banyak-yang-lebih-mendesak-ditindak-dibandingkan-kasus-ferry-irwandi/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/63544686849-Anggota_Komisi_I_DPR_Junico_Siahaan__Foto__Dok_vel20250417092448-250x190.jpeg',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Pansel BUMD Makassar Tegaskan Seleksi Tanpa Campur Tangan, Bantah Isu Nepotisme',
#   'link': 'https://fajar.co.id/2025/09/13/pansel-bumd-makassar-tegaskan-seleksi-tanpa-campur-tangan-bantah-isu-nepotisme/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/IMG-20250912-WA0165-250x190.jpg',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Indonesia Design Week 2025 Angkat Identitas Lokal, Tarik Dukungan Global',
#   'link': 'https://fajar.co.id/2025/09/13/indonesia-design-week-2025-angkat-identitas-lokal-tarik-dukungan-global/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/IMG-20250913-WA0004-250x190.jpg',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Menteri Pecatan Budi Arie Ucapkan Terima Kasih pada Budi Arie, Netizen Was-was',
#   'link': 'https://fajar.co.id/2025/09/13/menteri-pecatan-budi-arie-ucapkan-terima-kasih-pada-budi-arie-netizen-was-was/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/06/Eks-Menteri-Komunikasi-dan-Informatika-Budi-Arie-Setiadi-250x190.jpg',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Minta Pejabat Jaga Omongannya, Bachrum Achmadi: Nepal Fakta Bahwa Kemarahan Rakyat Tidak Terbendung…',
#   'link': 'https://fajar.co.id/2025/09/13/minta-pejabat-jaga-omongannya-bachrum-achmadi-nepal-fakta-bahwa-kemarahan-rakyat-tidak-terbendung/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/WhatsApp-Image-2025-09-08-at-12.36.16-250x190.jpeg',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Muncul Polling Jika Jenderal Gatot Nurmantyo Dipilih Prabowo Mengisi Jabatan Menko Polkam, Netizen Singgung Gibran',
#   'link': 'https://fajar.co.id/2025/09/13/muncul-polling-jika-jenderal-gatot-nurmantyo-dipilih-prabowo-mengisi-jabatan-menko-polkam-netizen-singgung-gibran/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2020/09/gatot-nurmantyo-1-300x200.jpg',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Presiden Prabowo Dinilai Manfaatkan Kerusuhan Agustus untuk Reshuffle, Selamat Ginting: Akan Ada Kocok Ulang Kabinet Tahun Ini',
#   'link': 'https://fajar.co.id/2025/09/13/presiden-prabowo-dinilai-manfaatkan-kerusuhan-agustus-untuk-reshuffle-selamat-ginting-akan-ada-kocok-ulang-kabinet-tahun-ini/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/08/Screenshot_2025-08-01-09-53-52-342-edit_com.google.android.youtube-250x190.jpg',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Sherina Munaf Diperiksa, Uya Kuya Datangi Polres Metro Jakarta Timur',
#   'link': 'https://fajar.co.id/2025/09/12/sherina-munaf-diperiksa-uya-kuya-datangi-polres-metro-jakarta-timur/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/uya-kuta-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Dikejar Sejumlah Orang Diduga Polisi, Lompat ke Sungai, AK Ditemukan Meninggal',
#   'link': 'https://fajar.co.id/2025/09/12/dikejar-sejumlah-orang-diduga-polisi-lompat-ke-sungai-ak-ditemukan-meninggal/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/garis-polisi-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Eliano Reijnders Debut Positif Bersama Persib Bandung, Belum Puas',
#   'link': 'https://fajar.co.id/2025/09/12/eliano-reijnders-debut-positif-bersama-persib-bandung-belum-puas/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/eliano-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Soal Reformasi Polri, Rudianto Lallo Sambut Positif Niat Presiden Prabowo',
#   'link': 'https://fajar.co.id/2025/09/12/soal-reformasi-polri-rudianto-lallo-sambut-positif-niat-presiden-prabowo/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/07/rudianto-lallo-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Olympicad VIII Bakal Digelar di Makassar, Ajang Adu Prestasi 10.000 Siswa Muhammadiyah Se-Indonesia',
#   'link': 'https://fajar.co.id/2025/09/12/olympicad-viii-bakal-digelar-di-makassar-ajang-adu-prestasi-10-000-siswa-muhammadiyah-se-indonesia/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/IMG_20250912_225424-250x190.jpg',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Pomdam Jaya Ungkap Peran Prajurit TNI FH yang Terlibat Pembunuhan Ilham Pradipta',
#   'link': 'https://fajar.co.id/2025/09/12/pomdam-jaya-ungkap-peran-prajurit-tni-fh-yang-terlibat-pembunuhan-ilham-pradipta/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/08/Muhammad-Ilham-Pradipta-Kacab-Bank-BUMN-Cempaka-Putih-yang-diculik-dan-dibunuh-250x190.jpg',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Prabowo Janji Reformasi Kepolisian, Selamat Ginting Bilang Kapolri Segera Diganti',
#   'link': 'https://fajar.co.id/2025/09/12/prabowo-janji-reformasi-kepolisian-selamat-ginting-bilang-kapolri-segera-diganti/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/08/kapolri-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Beda Jawaban RMS dan Benny K Harman soal RUU Perampasan Aset',
#   'link': 'https://fajar.co.id/2025/09/12/beda-jawaban-rms-dan-benny-k-harman-soal-ruu-perampasan-aset/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/rms-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Berapa Biaya Urus SKCK? Bisa Lewat Online, Masyarakat Tetap Pilih Antre di Loket',
#   'link': 'https://fajar.co.id/2025/09/12/berapa-biaya-urus-skck-bisa-lewat-online-masyarakat-tetap-pilih-antre-di-loket/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/Kapolres-Gowa-AKBP-Muhammad-Aldy-Sulaiman-memberikan-makanan-dan-minuman-gratis-kepada-warga-yang-mengurus-SKCK-250x190.jpeg',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Kecewa Kekalahan PSM, Bernardo Tavares: Terlalu Banyak Membuang-buang Waktu di Lapangan Tengah dan Tidak Fokus',
#   'link': 'https://fajar.co.id/2025/09/12/kecewa-kekalahan-psm-bernardo-tavares-terlalu-banyak-membuang-buang-waktu-di-lapangan-tengah-dan-tidak-fokus/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/psm-vs-persita-2-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Udang Beku yang Diekspor ke AS Tercemar Zat Radioaktif Cs-137, Menko Pangan Sebut Berasal dari Filipina',
#   'link': 'https://fajar.co.id/2025/09/12/udang-beku-yang-diekspor-ke-as-tercemar-zat-radioaktif-cs-137-menko-pangan-sebut-berasal-dari-filipina/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/udang-250x190.webp',
#   'summary': 'Tidak ada ringkasan'}]
